# %% [markdown]
# # Example of using the pattern memberships for custom Gene Set Enrichment
# - This notebook shows the combination of FlowSets with other downstream analyses.
# - While there is an overrepresentation analysis custom build for sets with partial memberships, also other methods could be considered.
# - It is shown how to extract the membership list for a pattern and how to apply a overrepresentation analysis on the list.
#
# ---
# Author: Felix Offensperger

# %%
# We do the same FlowSets as in the Flowsets_example.ipynb
import os, sys
sys.path.insert(0, "../")
from flowset import *

# Explicitly specify the schema for the columns
schema = {
    "baseMean": pl.Float32,
    "log2FoldChange": pl.Float32,
    "lfcSE": pl.Float32,
    "stat": pl.Float32,
    "pvalue": pl.Float32,
    "padj": pl.Float32,
    "comparison": pl.Utf8,
    "gene_id": pl.Utf8
}

# Read the cleaned results
deseq_results = pl.read_csv(
    './deseq2_results_37deg_10min_all_comparisons.csv',
    null_values=['NA'],
    schema=schema
)
deseq_results = deseq_results.with_columns(
    pl.col("log2FoldChange").fill_null(0),
    pl.col("padj").fill_null(1),
)
# Fuzzify the log2FoldChange values for each gene and comparison
explDFWide, mfFuzzy = LegacyFuzzifier.fuzzify(
    deseq_results, stepsize=0.01,
    symbol_column="gene_id", meancolName="log2FoldChange", sdcolName=None, exprcolName=None, clusterColName="comparison",
    mfLevels = ["strong_down","down","neutral","up", "strong_up"], centers=[-2, -1, 0, 1, 2],
    
)
# Create a FlowAnalysis object for the fuzzified data
# Define the mapping from comparison names to display names and order
series2name=(
       ("HSF1.KD vs Wildtype",'KO1 vs WT'),
        ("Double.KDKO vs Wildtype",'KO1+2 vs WT'),
       ("MSN24.KO vs Wildtype",'KO2 vs WT')
    )

fa= FlowAnalysis(explDFWide,"gene_id", series2name, mfFuzzy)
# Out:
# centers [-2, -1, 0, 1, 2]
# Creating Universe Range -14.0 -> 6.0 with step size 0.01
# /mnt/raidbio/extproj/projekte/FlowSets/small_example/../flowset.py:661: RuntimeWarning: invalid value encountered in divide
#   values = fuzz.trimf(self.universe, abc)/unscaledValues
# Mean Expr log2FoldChange col 1
# Expr Count cell_expr col 8
# SD None col None
# Cluster comparison col 6
# Combining over state:  False
# to_homogeneous: MSN24.KO vs Wildtype
# to_homogeneous: HSF1.KD vs Wildtype
# to_homogeneous: Double.KDKO vs Wildtype

# %%
# Now we define the pattern not for KO1 but for KO2
# Find genes with specific flow patterns and perform pathway analysis
relFlow=fa.flow_finder(["?","?"],minLevels=[None,None,"neutral"],maxLevels=["down","down","neutral"],verbose=False)

# Pathway analysis using GOslim and additional gene sets
pw_file="./goslim.gmt"
pwScores = fa.analyse_pathways(use_edges=relFlow,genesets_file=pw_file)
pwScores_signif=pwScores.sort_values("pw_coverage_pval", ascending=True).head(20)
display(pwScores_signif)
fa.plotORAresult(pwScores_signif, "GOslim", numResults=10, figsize=(6,6), outfile="./plots/goslim_pathway_analysis")
# Out:
# Loading pathways from ./goslim.gmt
# Identified 98 pathways
# Calculating p-values for groups [1, 2, 3, 4, 10, 50, 100]
#                                                  pwid  \
# 54                                    protein_folding
# 71                                   response_to_heat
# 61  proteolysis_involved_in_cellular_protein_catab...
# 68                            regulation_of_transport
# 32                                 meiotic_cell_cycle
# 62                                pseudohyphal_growth
# 34                              membrane_invagination
# 79                              RNA_catabolic_process
# 27                               histone_modification
# 65               regulation_of_organelle_organization
# 69                      response_to_chemical_stimulus
# 4                                  cell_morphogenesis
# 9                              chromatin_organization
# 47                              organelle_inheritance
# 60                                  protein_targeting
# 95                               vacuole_organization
# 64                regulation_of_DNA_metabolic_process
# 58  protein_modification_by_small_protein_conjugat...
# 50                                  protein_acylation
# 92                                      transposition
#
#                                                pwname    pwFlow  pwGenes  \
# 54                                    protein_folding  3.676439       21
# 71                                   response_to_heat  1.289424        9
# 61  proteolysis_involved_in_cellular_protein_catab...  3.499561       57
# 68                            regulation_of_transport  1.344375       14
# 32                                 meiotic_cell_cycle  3.328095       37
# 62                                pseudohyphal_growth  1.523366       18
# 34                              membrane_invagination  0.974079       13
# 79                              RNA_catabolic_process  1.525894       21
# 27                               histone_modification  2.229515       31
# 65               regulation_of_organelle_organization  2.656376       53
# 69                      response_to_chemical_stimulus  4.583926       93
# 4                                  cell_morphogenesis  0.755393        8
# 9                              chromatin_organization  3.315938       69
# 47                              organelle_inheritance  0.972683       15
# 60                                  protein_targeting  3.089097       49
# 95                               vacuole_organization  1.306634       21
# 64                regulation_of_DNA_metabolic_process  1.365145       22
# 58  protein_modification_by_small_protein_conjugat...  2.296746       39
# 50                                  protein_acylation  0.929612       16
# 92                                      transposition  0.390729        5
#
#      allPwFlow   allPwGenes  pw_gene_intersection  pw_coverage  \
# 54  204.590267  1058.000001                    21     0.175069
# 71  204.590267  1058.000001                     9     0.143269
# 61  204.590267  1058.000001                    57     0.061396
# 68  204.590267  1058.000001                    14     0.096027
# 32  204.590267  1058.000001                    37     0.089949
# 62  204.590267  1058.000001                    18     0.084631
# 34  204.590267  1058.000001                    13     0.074929
# 79  204.590267  1058.000001                    21     0.072662
# 27  204.590267  1058.000001                    31     0.071920
# 65  204.590267  1058.000001                    53     0.050120
# 69  204.590267  1058.000001                    93     0.049290
# 4   204.590267  1058.000001                     8     0.094424
# 9   204.590267  1058.000001                    69     0.048057
# 47  204.590267  1058.000001                    15     0.064846
# 60  204.590267  1058.000001                    49     0.063043
# 95  204.590267  1058.000001                    21     0.062221
# 64  204.590267  1058.000001                    22     0.062052
# 58  204.590267  1058.000001                    39     0.058891
# 50  204.590267  1058.000001                    16     0.058101
# 92  204.590267  1058.000001                     5     0.078146
#
#     genes_coverage  mean_coverage  pw_coverage_zscore  pw_coverage_pval  \
# 54        0.017970       0.003146            4.842491      6.411060e-07
# 71        0.006302       0.000903            2.274471      1.146885e-02
# 61        0.017105       0.001050            2.185771      1.441619e-02
# 68        0.006571       0.000631            2.036272      2.086150e-02
# 32        0.016267       0.001463            1.820476      3.434329e-02
# 62        0.007446       0.000630            1.631703      5.137106e-02
# 34        0.004761       0.000357            1.287243      9.900474e-02
# 79        0.007458       0.000542            1.206738      1.137665e-01
# 27        0.010897       0.000784            1.180403      1.189199e-01
# 65        0.012984       0.000651            1.178077      1.193829e-01
# 69        0.022405       0.001104            1.103830      1.348334e-01
# 4         0.003692       0.000349            1.066569      1.430833e-01
# 9         0.016208       0.000779            0.993686      1.601880e-01
# 47        0.004754       0.000308            0.929243      1.763815e-01
# 60        0.015099       0.000952            0.865242      1.934531e-01
# 95        0.006387       0.000397            0.836054      2.015622e-01
# 64        0.006673       0.000414            0.830068      2.032503e-01
# 58        0.011226       0.000661            0.717838      2.364286e-01
# 50        0.004544       0.000264            0.689785      2.451648e-01
# 92        0.001910       0.000149            0.664018      2.533395e-01
#
#     pw_coverage_adj_pval
# 54              0.000063
# 71              0.470929
# 61              0.470929
# 68              0.511107
# 32              0.673128
# 62              0.839061
# 34              0.936977
# 79              0.936977
# 27              0.936977
# 65              0.936977
# 69              0.936977
# 4               0.936977
# 9               0.936977
# 47              0.936977
# 60              0.936977
# 95              0.936977
# 64              0.936977
# 58              0.936977
# 50              0.936977
# 92              0.936977
# Index(['pwid', 'pwname', 'pwFlow', 'pwGenes', 'allPwFlow', 'allPwGenes',
#        'pw_gene_intersection', 'pw_coverage', 'genes_coverage',
#        'mean_coverage', 'pw_coverage_zscore', 'pw_coverage_pval',
#        'pw_coverage_adj_pval'],
#       dtype='object')
# False
# False
# (10, 14)

# %%
fa.plot_flow_memberships(use_edges=relFlow)
pattern_memberships = fa.calc_coarse_flow_memberships(use_edges=relFlow)

# %%
import numpy as np

pattern_memberships_pd = pattern_memberships.to_pandas()

high_membership = pattern_memberships_pd[pattern_memberships_pd['membership'] > 0.5]
display(high_membership)
# Out:
#         gene_id  membership
# 67        snR18    0.982868
# 79        snR35    0.627581
# 445     YAL005C    0.824098
# 498   YAL047W-A    0.881895
# 587     YBL022C    0.543202
# ...         ...         ...
# 6635    YPL032C    0.648335
# 6712    YPL106C    0.750238
# 6744    YPL136W    0.626336
# 7070    YPR158W    0.990313
# 7089  YPR170W-A    0.874812
#
# [77 rows x 2 columns]

# %%
import gseapy as gp #install via pip install gseapy

# ORA (Over-Representation Analysis)
ora_res = gp.enrichr(
    gene_list=high_membership['gene_id'].tolist(),
    gene_sets=pw_file,
    organism='Yeast',  # adjust if needed
    outdir=None,
    no_plot=True
)
display(ora_res.results.sort_values('Adjusted P-value', ascending=True).head(20))

# GSEA (Gene Set Enrichment Analysis)
# Prepare ranked list: gene_id to membership
rnk = pattern_memberships_pd
#rnk=high_membership
rnk = rnk.sort_values('membership', ascending=False).reset_index(drop=True)
gsea_res = gp.prerank(
    rnk=rnk ,
    gene_sets=pw_file,
    organism='Yeast',  # adjust if needed
    outdir=None,
    no_plot=False
)
display(gsea_res.res2d.sort_values('FWER p-val', ascending=True).head(20))
# Out:
#       Gene_set                                               Term Overlap  \
# 25  goslim.gmt                                    protein_folding    3/21
# 15  goslim.gmt                                 meiotic_cell_cycle    3/37
# 7   goslim.gmt                           cellular_ion_homeostasis    1/29
# 0   goslim.gmt                                  DNA_recombination    1/36
# 9   goslim.gmt                             chromosome_segregation    1/36
# 10  goslim.gmt                                        conjugation    1/31
# 8   goslim.gmt                             chromatin_organization    2/69
# 2   goslim.gmt                              RNA_catabolic_process    1/21
# 13  goslim.gmt                               histone_modification    2/31
# 27  goslim.gmt                                  protein_targeting    2/49
# 29  goslim.gmt                                pseudohyphal_growth    1/18
# 22  goslim.gmt                   peptidyl-amino_acid_modification    1/21
# 17  goslim.gmt                         mitochondrion_organization    2/73
# 19  goslim.gmt                                  nuclear_transport    1/36
# 16  goslim.gmt                          mitochondrial_translation    1/32
# 4   goslim.gmt                                 cell_morphogenesis     1/8
# 30  goslim.gmt                regulation_of_DNA_metabolic_process    1/22
# 31  goslim.gmt                           regulation_of_cell_cycle    2/50
# 28  goslim.gmt  proteolysis_involved_in_cellular_protein_catab...    2/57
# 23  goslim.gmt                                  protein_acylation    1/16
#
#      P-value  Adjusted P-value  Odds Ratio  Combined Score  \
# 25  0.002635          0.105385   15.521081       92.179971
# 15  0.013413          0.268255    8.193043       35.324719
# 7   0.342767          0.626382    3.686025        3.946646
# 0   0.407149          0.626382    2.938805        2.640744
# 9   0.407149          0.626382    2.938805        2.640744
# 10  0.361798          0.626382    3.437535        3.494840
# 8   0.255585          0.626382    2.679012        3.654707
# 2   0.261220          0.626382    5.164844        6.933255
# 13  0.068842          0.626382    6.368487       17.041707
# 27  0.150443          0.626382    3.884990        7.358839
# 29  0.228276          0.626382    6.067980        8.963626
# 22  0.261220          0.626382    5.164844        6.933255
# 17  0.277322          0.626382    2.518778        3.230521
# 19  0.407149          0.626382    2.938805        2.640744
# 16  0.371119          0.626382    3.325123        3.295971
# 4   0.108291          0.626382   14.296552       31.780250
# 30  0.271906          0.626382    4.919808        6.407061
# 31  0.155451          0.626382    3.801069        7.075405
# 28  0.191424          0.626382    3.298298        5.452964
# 23  0.205557          0.626382    6.864294       10.859535
#
#                       Genes
# 25  YAL005C;YDR214W;YDR258C
# 15  YDR446W;YDR155C;YDR207C
# 7                   YDR151C
# 0                   YDR446W
# 9                   YBL063W
# 10                  YCL027W
# 8           YDR155C;YCR082W
# 2                   YDR151C
# 13          YDR155C;YCR082W
# 27          YAL005C;YDR258C
# 29                  YDR207C
# 22                  YCR082W
# 17          YAL005C;YDR258C
# 19                  YAL005C
# 16                  YDR258C
# 4                   YCL027W
# 30                  YDL020C
# 31          YDR155C;YDR207C
# 28          YBL022C;YDL020C
# 23                  YCR082W
# 2025-06-26 10:56:55,974 [WARNING] Duplicated values found in preranked stats: 77.46% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#        Name                                            Term        ES  \
# 0   prerank           cellular_amino_acid_metabolic_process  0.885441
# 1   prerank                                     sporulation  0.889972
# 2   prerank                    response_to_oxidative_stress  0.898237
# 51  prerank                          response_to_starvation  0.837933
# 50  prerank                              organelle_assembly  0.836883
# 49  prerank                             pseudohyphal_growth  0.846007
# 48  prerank                                      DNA_repair  0.817818
# 47  prerank                               nuclear_transport  0.831709
# 46  prerank                                 DNA_replication  0.829786
# 44  prerank  generation_of_precursor_metabolites_and_energy   0.83856
# 52  prerank                      response_to_osmotic_stress  0.845829
# 43  prerank                 response_to_DNA_damage_stimulus   0.81816
# 42  prerank                peptidyl-amino_acid_modification   0.84561
# 41  prerank                         Golgi_vesicle_transport  0.828765
# 40  prerank                        cellular_ion_homeostasis   0.83904
# 39  prerank                  carbohydrate_metabolic_process  0.824556
# 45  prerank                         lipid_metabolic_process  0.822855
# 53  prerank                                 membrane_fusion  0.838766
# 55  prerank      regulation_of_protein_modification_process   0.84135
# 38  prerank             regulation_of_DNA_metabolic_process  0.847751
#
#          NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0   1.052944     0.048       1.0      0.997   5/52   6.96%
# 1   1.050243     0.095       1.0      0.999   5/35  10.10%
# 2   1.049146     0.133       1.0      0.999   1/25   4.60%
# 51  0.977971     0.635  0.965561        1.0  11/24  16.31%
# 50  0.978539     0.655  0.976295        1.0   9/28  13.58%
# 49  0.979036     0.621     0.988        1.0   9/18  13.11%
# 48  0.979641     0.797  0.998998        1.0  10/71  16.10%
# 47  0.980204     0.662       1.0        1.0   9/36  12.05%
# 46  0.980917     0.659       1.0        1.0   9/40  16.95%
# 44  0.982468     0.609       1.0        1.0   6/28  13.53%
# 52  0.977133     0.646  0.958949        1.0   3/17  15.42%
# 43  0.982876     0.796       1.0        1.0  10/88  12.83%
# 42  0.983445     0.579       1.0        1.0   5/21  14.92%
# 41  0.983518     0.678       1.0        1.0  18/48  17.26%
# 40  0.984142     0.612       1.0        1.0   6/29  12.88%
# 39  0.986058     0.683       1.0        1.0  15/65  16.59%
# 45  0.981983     0.729       1.0        1.0  15/62  14.29%
# 53  0.975963     0.668  0.957824        1.0   9/23  15.37%
# 55  0.973487     0.659  0.954712        1.0   6/16  15.91%
# 38  0.987255     0.545       1.0        1.0   6/22  13.37%
#
#                                            Lead_genes
# 0             YDR207C;YAL012W;YDR421W;YAL013W;YDR037W
# 1             YDR155C;YDR104C;YBL058W;YDR208W;YDR099W
# 2                                             YBR216C
# 51  YBL078C;YBL058W;YDR170C;YDL149W;YDL126C;YBR097...
# 50  YBL078C;YAL026C;YBL058W;YDR170C;YDL149W;YBL105...
# 49  YDR207C;YDL159W;YDR480W;YDL230W;YBR057C;YDR099...
# 48  YDL020C;YAR007C;YDR381W;YDL105W;YDR224C;YDR159...
# 47  YAL005C;YDR381W;YBR111W-A;YDR432W;YBL103C;YDR3...
# 46  YAR007C;YAL013W;YBR060C;YBR057C;YDR099W;YAL021...
# 44    YAL038W;YCR012W;YBL058W;YDR099W;YBR196C;YDR028C
# 52                            YBR260C;YCL032W;YDR420W
# 43  YDL020C;YBR173C;YAR007C;YDR381W;YDL105W;YDR224...
# 42            YCR082W;YDR176W;YDR145W;YDR392W;YBR198C
# 41  YBL078C;YCR067C;YDR246W;YAL026C;YDR484W;YDR170...
# 40    YDR151C;YCL017C;YCR044C;YDR205W;YDR182W;YDR456W
# 39  YDR207C;YBR018C;YAL038W;YCR012W;YBL058W;YAL013...
# 45  YDR207C;YDR284C;YAL051W;YCL004W;YDR302W;YDR319...
# 53  YDL077C;YDR189W;YAL030W;YDR080W;YDL126C;YBR179...
# 55    YDL159W;YDR103W;YDR099W;YDL127W;YAR002W;YCR059C
# 38  YDL020C;YDR014W-A;YAL013W;YDL070W;YAL021C;YDL220C

# %%
import matplotlib.pyplot as plt

# Extract p-values from each method
# 1. FlowSet pathway analysis (pwScores): 'pw_coverage_pval'
# 2. Enrichr ORA (ora_res): 'Adjusted P-value'
# 3. GSEA prerank (gsea_res): 'FWER p-val'

# Prepare DataFrames for merging
pw_df = pwScores[['pwid', 'pw_coverage_adj_pval']].rename(columns={'pwid': 'pwname', 'pw_coverage_adj_pval': 'FlowSet_pval'})
ora_df = ora_res.results[['Term', 'Adjusted P-value']].rename(columns={'Term': 'pwname', 'Adjusted P-value': 'ORA_pval'})
gsea_df = gsea_res.res2d[['Term', 'FWER p-val']].rename(columns={'Term': 'pwname', 'FWER p-val': 'GSEA_pval'})

# Merge on pathway name
merged = pw_df.merge(ora_df, on='pwname', how='outer').merge(gsea_df, on='pwname', how='outer')

# Drop rows with all NaNs
merged = merged.dropna(subset=['FlowSet_pval', 'ORA_pval', 'GSEA_pval'], how='all')

# Plot pairwise scatter plots
plt.figure(figsize=(8,8))
plt.scatter(merged['FlowSet_pval'], merged['ORA_pval'], label='FlowSet vs ORA', alpha=0.7)
plt.scatter(merged['FlowSet_pval'], merged['GSEA_pval'], label='FlowSet vs GSEA', alpha=0.7)
plt.scatter(merged['ORA_pval'], merged['GSEA_pval'], label='ORA vs GSEA', alpha=0.7)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('p-value (log scale)')
plt.ylabel('p-value (log scale)')
plt.legend()
plt.title('Comparison of p-values from FlowSets, ORA, and GSEA')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.show()

# %% [markdown]
# As most of the memberships of the pattern are zero the fuzzy geneset overrepresentation method behaves in this example like ORA.
# In other examples with all features belonging partially to the pattern, it resembles a ranked approach.
# It can be seen that especially for small feature sets the GSEA is not a universal solution.
